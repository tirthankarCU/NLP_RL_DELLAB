# %%
from google.colab import drive
from os.path import join  

def mount_drive(ROOT):
    drive.mount(ROOT, force_remount=True)

ROOT = '/content/drive'
mount_drive(ROOT)

MY_GOOGLE_DRIVE_PATH = 'MyDrive/RL_NLP/' 
PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)
print("PROJECT_PATH: ", PROJECT_PATH)   
# %cd "{PROJECT_PATH}"

# %%
# !pip3 install virtualenv
# !virtualenv -p python3.8.10 python38

# !source /content/drive/MyDrive/Colab/RL_NLP/python38/bin/activate
# !python --version

# %%
# !pip install -r "{PROJECT_PATH}/metadata/requirements.txt"

# %% [markdown]
# ## First time only run.
#
# !git clone https://github.com/Farama-Foundation/gym-examples
#
# %cd gym-examples
#
# !pip install -e .
#
# %cd ..

# %% [markdown]
# # RUN FROM HERE.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# %cd gym-examples
# !pip install -e .
# Out:
# \\wsl.localhost\Ubuntu\home\tirthankarmittra\Desktop\IndependentStudy1_Code\NLP_RL_DELLAB\gym-examples
# Obtaining file:///Z:/home/tirthankarmittra/Desktop/IndependentStudy1_Code/NLP_RL_DELLAB/gym-examples
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: gym==0.26.0 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from gym-examples==0.0.1) (0.26.0)
# Requirement already satisfied: pygame==2.1.0 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from gym-examples==0.0.1) (2.1.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from gym==0.26.0->gym-examples==0.0.1) (4.11.3)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from gym==0.26.0->gym-examples==0.0.1) (1.21.5)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from gym==0.26.0->gym-examples==0.0.1) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from gym==0.26.0->gym-examples==0.0.1) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from importlib-metadata>=4.8.0->gym==0.26.0->gym-examples==0.0.1) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\tirth\.conda\envs\tf\lib\site-packages (from importlib-metadata>=4.8.0->gym==0.26.0->gym-examples==0.0.1) (4.3.0)
# Installing collected packages: gym-examples
#   Running setup.py develop for gym-examples
# Successfully installed gym-examples

# %%
import gym
import gym_examples
import numpy as np

episodes=2
env = gym.make('gym_examples/RlNlpWorld-v0',render_mode="human")

# %%
def policy(observation):
    return np.random.randint(0,6)

dbg=False
for _ in range(episodes):
    cumulative_reward,steps=0,0
    observation, info = env.reset(seed=42)
    cnt=0
    while True:
        action = policy(observation)  # User-defined policy function
        observation, reward, terminated, truncated, info = env.step(action)
        cumulative_reward+=reward
        steps+=1
        if dbg==True:
            print(f'cumulative_reward {cumulative_reward}; action {action}')
            plt.figure()
            plt.imshow(observation["visual"])
        if terminated or truncated:
            break
    print(f'Cumulative Reward ~ {cumulative_reward}; TimeTaken ~ {steps}')
env.close()
# Out:
# <class 'numpy.ndarray'>
# Cumulative Reward ~ -49; TimeTaken ~ 51
# <class 'numpy.ndarray'>
# Cumulative Reward ~ -43; TimeTaken ~ 51
